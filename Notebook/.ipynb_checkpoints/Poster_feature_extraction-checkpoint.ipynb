# %%
import sys
sys.path.append('/Users/zishuoli/Doc/project/Feature_extractor/lib')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/zishuoli/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/zishuoli/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/zishuoli/anaconda/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/zishuoli/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ...

# %%
from extractor import Img_extractor

# %% [markdown]
# # Extract raw arr from local & url path

# %%
extractor = Img_extractor.Img_extractor()

# %%
path_local = '/Users/zishuoli/Doc/project/Feature_extractor/Image/tmdb_movie_poster/The Matrix/603.jpg'
# path_url = 'http://image.tmdb.org/t/p/w185//lh4aGpd3U9rm9B8Oqr6CUgQLtZL.jpg'
path_url = 'http://image.tmdb.org/t/p/w185//hEpWvX6Bp79eLxY1kX5ZZJcme5U.jpg'

# %%
arr_local = extractor.get_raw_arr(path_local)
# Out:
# load Image locally

# %%
arr_url = extractor.get_raw_arr(path_url)
# Out:
# load Image from url

# %% [markdown]
# # Extract features from local & url path

# %%
features_local = extractor.get_features(path_local)
# Out:
# load Image locally

# %%
features_url = extractor.get_features(path_url)
# Out:
# load Image from url

# %% [markdown]
# # Arr to features

# %%
features_local = extractor.arr_2_features(arr_local)
features_url = extractor.arr_2_features(arr_url)

# %%
print("features_local dim: {}".format(features_local.shape))
print("features_url dim: {}".format(features_url.shape))
# Out:
# features_local dim: (1, 1000)
# features_url dim: (1, 1000)

# %% [markdown]
# # Show image from extracted arr

# %%
extractor.show_img(arr_local)

# %%
extractor.show_img(arr_url)
